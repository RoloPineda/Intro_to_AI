# %% [markdown]
# # Creating a simple regression Neural Network Practice
#
# Now it's time to put your new knowledge to the test. This notebook has a series of different challenges and tests for you to go over. Make sure to only edit the code blocks that are indicated.

# %%
import tensorflow as tf
import numpy as np

# %% [markdown]
# ### Challenge 1:
# Your task is to create a model that solves the linear equation y = 2x+30

# %%
def model1():
    """This model solves the equation y = 2x+30"""
    ### YOUR CODE HERE ###
    input_values = None
    output_values = None
    ### END CODE
    model = tf.keras.Sequential([tf.keras.layers.Dense(units=1, input_shape=[1])])

    model.compile(optimizer=tf.keras.optimizers.Adam(0.1), loss='mean_squared_error')

    ### YOUR CODE HERE ###
    model.fit(input_values, output_values, epochs=None, verbose=True)
    ### END CODE
    return model

# %%
first_model = model1()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [63], in <cell line: 1>()
# ----> 1 first_model = model1()
#
# Input In [62], in model1()
#       9 model.compile(optimizer=tf.keras.optimizers.Adam(0.1), loss='huber_loss')
#      11 ### YOUR CODE HERE ###
# ---> 12 model.fit(input_values, output_values, epochs=None, verbose=False)
#      13 ### END CODE
#      14 return model
#
# File ~/miniforge3/envs/introToAI/lib/python3.10/site-packages/keras/utils/traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~/miniforge3/envs/introToAI/lib/python3.10/site-packages/keras/engine/data_adapter.py:985, in select_data_adapter(x, y)
#     982 adapter_cls = [cls for cls in ALL_ADAPTER_CLS if cls.can_handle(x, y)]
#     983 if not adapter_cls:
#     984   # TODO(scottzhu): This should be a less implementation-specific error.
# --> 985   raise ValueError(
#     986       "Failed to find data adapter that can handle "
#     987       "input: {}, {}".format(
#     988           _type_name(x), _type_name(y)))
#     989 elif len(adapter_cls) > 1:
#     990   raise RuntimeError(
#     991       "Data adapters should be mutually exclusive for "
#     992       "handling inputs. Found multiple adapters {} to handle "
#     993       "input: {}, {}".format(
#     994           adapter_cls, _type_name(x), _type_name(y)))
#
# ValueError: Failed to find data adapter that can handle input: <class 'NoneType'>, <class 'NoneType'>

# %%
print('Testing model (close predictions are fine, try to get at least within 0.99 difference)\n')
print(f'Expected result: 37 ---> Got: {first_model.predict([3.5], verbose=False)}')
print(f'Expected result: 46.19 --- Got: {first_model.predict([8.09], verbose=False)}')

# %% [markdown]
# ### Challenge 2
#
# Your task is to create a model that solves the equation $a = 35(44*b - 10.56$
#
# Hint: For this model I recommend adjusting the learning rate for the optimizer. Also don't be afraid to add more data and/or increase the number of epochs

# %%
def model2():
    """This model solves the equation a = 35(44*b - 10.56)"""
    ### YOUR CODE HERE ###
    input_values = None
    output_values = None
    model = None

    ### END CODE

    model.compile(None, loss='mean_absolute_error')

    ### YOUR CODE HERE ###
    model.fit(None, None, epochs=None, verbose=True)
    ### END CODE
    return model

# %%
second_model = model2()
# Out:
# 2022-06-01 23:16:14.673015: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
print('Testing model (close predictions are fine, try to get at least within 0.99 difference)\n')
print(f'Expected result: -354.2 ---> Got: {second_model.predict([0.01], verbose=False)}')
print(f'Expected result: 1170.4 --- Got: {second_model.predict([1.0], verbose=False)}')
# Out:
# Testing model (close predictions are fine, try to get at least within 0.99 difference)
#
# Expected result: -354.2 ---> Got: [[-354.3246]]
# Expected result: 1170.4 --- Got: [[1170.1143]]
# 2022-06-01 23:16:35.553095: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
